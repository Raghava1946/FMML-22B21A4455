# %% [markdown]
# <a href="https://colab.research.google.com/github/Raghava1946/FMML-22B21A4455/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-03 05:51:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   207MB/s    in 0.3s
#
# 2024-04-03 05:51:09 (207 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 30204  1711.08995v1  The objective of unsupervised domain adaptatio...    cs
# 11670  1609.03769v1  We derive a new proof to show that the increme...  stat
# 22105   1411.5799v2  Factor analysis provides linear factors that d...  stat
# 17552  1712.01813v1  A major challenge in Entity Linking (EL) is ma...    cs
# 25631  1510.07391v2  Vehicle color information is one of the import...    cs
# ...             ...                                                ...   ...
# 8563   1705.03595v1  The paper presents a novel concept for collabo...    cs
# 6635   1704.05194v1  CTR prediction in real-world business is a dif...  stat
# 312     1409.2944v2  Collaborative filtering (CF) is a successful a...    cs
# 40077  1710.05732v2  The color sensation evoked by an object depend...    cs
# 7109   1710.05476v3  Excellent ranking power along with well calibr...  stat
#
#                                                    title  year  \
# 30204  Unsupervised Domain Adaptation with Similarity...  2017
# 11670  Analysis of Kelner and Levin graph sparsificat...  2016
# 22105                              Group Factor Analysis  2014
# 17552                Neural Cross-Lingual Entity Linking  2017
# 25631  Vehicle Color Recognition using Convolutional ...  2015
# ...                                                  ...   ...
# 8563   Collaborative Descriptors: Convolutional Maps ...  2017
# 6635   Learning Piece-wise Linear Models from Large S...  2017
# 312    Collaborative Deep Learning for Recommender Sy...  2014
# 40077   Generating Reflectance Curves from sRGB Triplets  2017
# 7109                          Calibrated Boosting-Forest  2017
#
#                                                 keywords
# 30204  [objective, unsupervised, adaptation, classifi...
# 11670  [incremental, resparsification, algorithm, spa...
# 22105  [relationships, individual, variables, classic...
# 17552  [challenge, effective, contextual, information...
# 25631  [information, important, recognition, convolut...
# ...                                                  ...
# 8563   [collaborative, descriptors, convolutional, pr...
# 6635   [prediction, difficult, nonlinear, introduce, ...
# 312    [collaborative, filtering, successful, recomme...
# 40077  [sensation, distribution, illumination, reflec...
# 7109   [excellent, calibrated, probability, estimates...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 30204    [objective, unsupervised, adaptation, classifi...
# 11670    [incremental, resparsification, algorithm, spa...
# 22105    [relationships, individual, variables, classic...
# 17552    [challenge, effective, contextual, information...
# 25631    [information, important, recognition, convolut...
#                                ...
# 25179    [alignment, locations, landmarks, attention, e...
# 33480    [solutions, intrusion, detection, artificial, ...
# 24149    [supervised, intrinsic, decomposition, compone...
# 10150    [empirical, discovering, collective, populatio...
# 35840    [introduce, representation, theoretic, represe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8854 words.
# Out of those 4570 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4f5854ed-d359-4485-9e94-f9497d0a727e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f5854ed-d359-4485-9e94-f9497d0a727e")) {                    Plotly.newPlot(                        "4f5854ed-d359-4485-9e94-f9497d0a727e",                        [{"x":["scenarios","unsupervised","invariant","objective","inference","adaptation","performed","effective","indistinguishable","classifier","connected","categorical","associated","classifiers","distribution","similarity","distances","performance","prototype","unlabeled","approaches","classification","representations","prototypes","computing","different","subsequent","algorithm","martingale","sparsification","dependencies","rigorously","streaming","inequalities","probability","incremental","formulation","outperforming","activation","variables","dimensional","extensions","classical","naturally","straightforward","variational","implementations","formulated","individual","applicability","canonical","illustrating","represents","alternative","relationships","hierarchical","resulting","structural","accurately","solutions","correlation","demonstrated","exacerbates","contextual","languages","disambiguate","embeddings","information","convolution","dissimilarities","challenge","surprisingly","empirical","candidate","fragments","documents","wikipedia","perspectives","similarities","outperform","architecture","iterations","krizhevsky","procedure","introduce","decreasing","convolutional","important","recognition","optimized","eliminating","navigation","investigation","inaccurate","detecting","experimental","autonomous","advancement","following","introducing","researchers","attention","enhancement","techniques","conducted","increasing","eventually","environmental","outstanding","successful","tremendously","independent","censoring","occurrence","modelling","presented","vocabulary","preference","selection","principle","popularity","generated","determine","requirements","particular","appropriate","summarizing","intelligence","application","decisions","literature","analyzing","mechanisms","understanding","depending","distributed","automation","landscape","scalability","essential","simulated","probabilistic","projection","highlight","component","associative","generalization","numerical","properties","experiments","implement","astronomical","explicitly","reinforcement","constructing","recording","efficient","construct","nonparametric","normalised","reversible","transition","specifically","dirichlet","epigenomics","characterised","processes","predictive","undirected","enforcing","completely","empirically","thousands","increasingly","operation","containing","dimensions","improvement","evaluations","connection","available","prediction","establishing","secondary","educational","predicting","affiliated","collected","bankruptcy","detection","knowledge","discovers","educators","opportunities","capabilities","management","attributes","ecosystem","education","analytical"],"y":[101,128,59,160,236,60,136,266,5,123,80,11,130,104,208,150,27,865,24,35,447,505,212,4,134,741,29,813,2,0,46,10,7,3,158,29,81,36,33,145,182,31,98,68,26,57,45,38,133,54,24,4,40,105,76,93,151,64,68,163,69,94,2,35,98,7,66,690,37,2,130,26,171,58,7,64,23,19,34,101,224,26,2,131,307,6,357,318,363,58,11,33,27,9,64,385,58,7,87,50,79,181,38,375,68,93,7,20,9,77,3,130,0,25,41,177,37,36,153,52,20,168,78,41,296,81,8,80,246,62,133,60,57,152,32,108,12,16,26,59,67,167,39,38,106,5,102,70,215,626,83,1,74,120,31,5,412,82,20,1,5,32,164,22,0,2,115,51,11,9,31,79,29,53,50,55,39,128,53,48,326,224,20,6,3,82,2,74,1,316,352,10,2,16,47,59,61,2,8,27],"type":"bar"},{"x":["scenarios","unsupervised","invariant","objective","inference","adaptation","performed","effec ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4570,), (4570, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(0, 255, 0, 0.30065975494816216);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>on</span> <span style=''>Discrete</span> <span style=''>Lattices</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>data</span> <span style=''>that</span> <span style=''>reside</span> <span style=''>on</span> <span style=''>discrete</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.34649910233393166);'>dimensional</span> <span style=''>lattices</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Canonical</span> <span style=''>examples</span> <span style=''>for</span> <span style=''>this</span> <span style=''>setting</span> <span style=''>are</span> <span style=''>found</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6945812807881774);'>segmentation</span> <span style=''>and</span> <span style=''>key</span> <span style=''>point</span> <span style='background-color:rgba(0, 255, 0, 0.6114285714285714);'>extraction</span> <span style=''>Our</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.30065975494816216);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>where</span> <span style=''>clusters</span> <span style=''>result</span> <span style=''>from</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizes</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.39024390243902446);'>divergence</span> <span style=''>measure</span> <span style=''>We</span> <span style=''>replace</span> <span style=''>costly</span> <span style='background-color:rgba(0, 255, 0, 0.45698924731182794);'>processing</span> <span style=''>steps</span> <span style=''>in</span> <span style=''>the</span> <span style=''>original</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5454545454545454);'>convolutions</span> <span style=''>These</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3043478260869564);'>implementations</span> <span style=''>and</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>significantly</span> <span style=''>reduce</span> <span style=''>runtime</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>therefore</span> <span style=''>bridges</span> <span style=''>a</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.45698924731182794);'>processing</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Modelling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Competitive</span> <span style=''>Sports</span> <span style=''>Bradley</span> <span style=''>Terry</span> <span style=''>Élő</span> <span style=''>Models</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>and</span> <span style=''>On</span> <span style=''>Line</span> <span style=''>Learning</span> <span style=''>of</span> <span style=''>Paired</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Competition</span> <span style=''>Outcomes</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competitive</span> <span style=''>sports</span> <span style=''>outcomes</span> <span style=''>has</span> <span style=''>received</span> <span style=''>much</span> <span style=''>recent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>from</span> <span style=''>the</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>communities</span> <span style=''>In</span> <span style=''>the</span> <span style=''>real</span> <span style=''>world</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>outcome</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>the</span> <span style=''>seminal</span> <span style=''>ElHo</span> <span style=''>update</span> <span style=''>still</span> <span style=''>remains</span> <span style=''>after</span> <span style=''>more</span> <span style=''>than</span> <span style=''>50</span> <span style=''>years</span> <span style=''>a</span> <span style=''>valuable</span> <span style=''>baseline</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>upon</span> <span style=''>though</span> <span style=''>in</span> <span style=''>its</span> <span style=''>original</span> <span style=''>form</span> <span style=''>it</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heuristic</span> <span style=''>and</span> <span style=''>not</span> <span style=''>a</span> <span style=''>proper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Mathematically</span> <span style=''>the</span> <span style=''>ElHo</span> <span style=''>rating</span> <span style=''>system</span> <span style=''>is</span> <span style=''>very</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style=''>Bradley</span> <span style=''>Terry</span> <span style=''>models</span> <span style=''>which</span> <span style=''>are</span> <span style=''>usually</span> <span style=''>used</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanatory</span> <span style=''>fashion</span> <span style=''>rather</span> <span style=''>than</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>or</span> <span style=''>on</span> <span style=''>line</span> <span style=''>learning</span> <span style=''>setting</span> <span style='backgroun ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.9047619047619048);'>Hamiltonian</span> <span style=''>operator</span> <span style=''>for</span> <span style=''>spectral</span> <span style=''>shape</span> <span style=''>analysis</span> <br/><br/><span style=''>Many</span> <span style=''>shape</span> <span style=''>analysis</span> <span style=''>methods</span> <span style=''>treat</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>an</span> <span style=''>object</span> <span style=''>as</span> <span style=''>a</span> <span style=''>metric</span> <span style=''>space</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>captured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>Laplace</span> <span style=''>Beltrami</span> <span style=''>operator</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>adapt</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style='background-color:rgba(255, 0, 0, 0.9047619047619048);'>Hamiltonian</span> <span style=''>operator</span> <span style=''>from</span> <span style=''>quantum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>mechanics</span> <span style=''>to</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style=''>shape</span> <span style=''>analysis</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>addition</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>function</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generator</span> <span style=''>for</span> <span style=''>dual</span> <span style=''>spaces</span> <span style=''>in</span> <span style=''>which</span> <span style=''>shape</span> <span style='background-color:rgba(0, 255, 0, 0.45698924731182794);'>processing</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.40206185567010305);'>performed</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>solving</span> <span style='background-color:rgba(255, 0, 0, 0.5546875);'>variational</span> <span style=''>problems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.9047619047619048);'>Hamiltonian</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.48571428571428577);'>perturbation</span> <span style=''>theory</span> <span style=''>for</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>eigenvectors</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>suggested</span> <span style=''>operator</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>produce</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functional</span> <span style=''>spaces</span> <span style=''>to</span> <span style=''>operate</span> <span style=''>with</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demons ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style=''>noise</span> <br/><br/><span style=''>A</span> <span style=''>popular</span> <span style=''>approach</span> <span style=''>within</span> <span style=''>the</span> <span style=''>signal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>and</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>communities</span> <span style=''>consists</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style=''>signals</span> <span style=''>as</span> <span style=''>sparse</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>atoms</span> <span style=''>selected</span> <span style=''>from</span> <span style=''>a</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>While</span> <span style=''>this</span> <span style=''>paradigm</span> <span style=''>has</span> <span style=''>led</span> <span style=''>to</span> <span style=''>numerous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successes</span> <span style=''>in</span> <span style=''>various</span> <span style=''>fields</span> <span style=''>ranging</span> <span style=''>from</span> <span style=''>image</span> <span style=''>to</span> <span style=''>audio</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>there</span> <span style=''>have</span> <span style=''>only</span> <span style=''>been</span> <span style=''>a</span> <span style=''>few</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arguments</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supporting</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evidences</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>or</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>whose</span> <span style=''>local</span> <span style=''>minima</span> <span style=''>have</span> <span style=''>not</span> <span style=''>been</span> <span style=''>fully</span> <span style=''>analyzed</span> <span style=''>yet</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>of</span> <span style=''>sparse</span> <span style=''>signals</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>with</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>sparse</span> <span style=''>coding</span> <span style=''>admits</span> <span style=''>a</span> <span style=''>local</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09675116029989289)
# 	evaluation (0.09782220635487326)
# 	challenging (0.1017493752231346)
# 	experimental (0.13745091038914672)
# 	knowledge (0.12566940378436273)
# 	information (0.24634059264548375)
# 	detection (0.11281685112459836)
# 	different (0.26454837558014993)
# 	convolutional (0.12745448054266334)
# 	recognition (0.12959657265262406)
#
# Some Statistics words are:
# 	stochastic (0.13206603301650827)
# 	algorithm (0.38019009504752377)
# 	estimation (0.16508254127063532)
# 	variables (0.1470735367683842)
# 	theoretical (0.15107553776888444)
# 	statistical (0.1585792896448224)
# 	distribution (0.18309154577288644)
# 	inference (0.1950975487743872)
# 	dimensional (0.1875937968984492)
# 	regression (0.17958979489744872)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="46c6232c-f537-4626-9177-68ab5e89d72c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46c6232c-f537-4626-9177-68ab5e89d72c")) {                    Plotly.newPlot(                        "46c6232c-f537-4626-9177-68ab5e89d72c",                        [{"x":["scenarios","unsupervised","invariant","objective","inference","adaptation","performed","effective","indistinguishable","classifier","connected","categorical","associated","classifiers","distribution","similarity","distances","performance","prototype","unlabeled","approaches","classification","representations","prototypes","computing","different","subsequent","algorithm","martingale","sparsification","dependencies","rigorously","streaming","inequalities","probability","incremental","formulation","outperforming","activation","variables","dimensional","extensions","classical","naturally","straightforward","variational","implementations","formulated","individual","applicability","canonical","illustrating","represents","alternative","relationships","hierarchical","resulting","structural","accurately","solutions","correlation","demonstrated","exacerbates","contextual","languages","disambiguate","embeddings","information","convolution","dissimilarities","challenge","surprisingly","empirical","candidate","fragments","documents","wikipedia","perspectives","similarities","outperform","architecture","iterations","krizhevsky","procedure","introduce","decreasing","convolutional","important","recognition","optimized","eliminating","navigation","investigation","inaccurate","detecting","experimental","autonomous","advancement","following","introducing","researchers","attention","enhancement","techniques","conducted","increasing","eventually","environmental","outstanding","successful","tremendously","independent","censoring","occurrence","modelling","presented","vocabulary","preference","selection","principle","popularity","generated","determine","requirements","particular","appropriate","summarizing","intelligence","application","decisions","literature","analyzing","mechanisms","understanding","depending","distributed","automation","landscape","scalability","essential","simulated","probabilistic","projection","highlight","component","associative","generalization","numerical","properties","experiments","implement","astronomical","explicitly","reinforcement","constructing","recording","efficient","construct","nonparametric","normalised","reversible","transition","specifically","dirichlet","epigenomics","characterised","processes","predictive","undirected","enforcing","completely","empirically","thousands","increasingly","operation","containing","dimensions","improvement","evaluations","connection","available","prediction","establishing","secondary","educational","predicting","affiliated","collected","bankruptcy","detection","knowledge","discovers","educators","opportunities","capabilities","management","attributes","ecosystem","education","analytical","university","employment","proactive","algorithms","structure","efficiently","subsequence","programming","computation","computationally","absolutely","geometric","synthetically","outperforms","construction","contribute","efficiency","aggregation","motivation","therefore","interesting","optimistic","technical","pragmatic","environments","counterexample","assumptions","conjecture","considered","posterior","additional","linguistic","components","limitations","annotated","dependency","evaluation","utterances","surpasses","representation","variation","framework","capturing","estimates","overcomes","difficulty","potentially","intermediate","estimator","exacerbated","covariance","demonstrate","regularized","consequences","likelihood","optimizat ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sparsification
# 	censoring
# 	epigenomics
# 	assimilated
# 	crowdworkers
# 	meteorological
# 	temperatures
# 	permeates
# 	recasting
# 	heteroscedastic
# 	homoscedastic
# 	connectome
# 	retention
# 	duplicate
# 	corollary
# 	catalogue
# 	characterisation
# 	sparsifies
# 	subsamples
# 	regularised
# Some words which never appear in Statistics papers:
# 	exacerbates
# 	disambiguate
# 	fragments
# 	navigation
# 	affiliated
# 	educators
# 	ecosystem
# 	proactive
# 	synthetically
# 	quantifiers
# 	quantifier
# 	panchromatic
# 	differentiating
# 	introspection
# 	adaptability
# 	contrasts
# 	excitation
# 	occlusions
# 	discontinuous
# 	regularities

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.069367710251688e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
